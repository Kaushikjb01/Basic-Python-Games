# %%
name = input("Type in your name: ")
print("Welcome",name,"to this adventure where you make your choices!!")

print("\nSo let's start\n")
answer = input("You are walking on a road and the road divides into 3 different roads, one goes right, one to the left, and one straight.\nWhich one would you choose? ").lower()

if answer == "right":
    answer = input("\nNow while walking you see a homeless man on the side of the road who looks like might not have eaten anything for days and asks you for help. \nDo you help him (yes/no)? ").lower()
    if answer == "yes":
        print("\nWell well, turns out it was a youtuber doing a social experiment and looking at your good gesture he gifts you a $100,000 and a brand new Tesla and you drive home...\nLooks like you wonnn, greattt Jobb")
    elif answer == "no":
        answer=input("\nNo worries, so you keep walking and suddenly there is a minivan next to you and 4 masked men come out of it and kidnap you. You can either cooperate with them or fight them off. What do you do (cooperate/fight)? ")
        if answer == "cooperate":
            print("\nOh so it turns out they were your friends and you partied hard that night and went home happy...\bLooks like you wonnnn!!!")
        elif answer == "fight":
            print("\nOh no, they turned out to be skilled muscle for hire and your fighting skills were no match and you end up dead ;_;\nYou lost!!")
        else:
            print("\nNot a valid option...\nYou lose!!")
    else:
        print("\nNot a valid option...\nYou lose!!")
elif answer == "left":
    answer = input("\nSo you take a left and keep walking walking and walking...\nAfter some time you encounter a river....there is a bridge over it. Do you swin across the river or do you walk over the bridge (swim/walk)? ").lower()
    if answer == "swim":
        print("\nOh no, there was a crocodile waiting for you there and you end up being its dinner...\nLooks like you lose!!")
    elif answer == "walk":
        answer = input("\nYou take the bridge and notice a person on the edge, you go near to take a closer look turns out its a girl trying to jump off the edge to end her suffering.\nDo you go and save that girl (yes/no)? ").lower()
        if answer == "yes":
            print("\nSo you go on and try to help her, but she took you with her and you both fell into the river but you know how to swim and you saved her life, turns out she is the daughter of a billionaire and get rewarded with $20,000,000 and the girl gets all the help she needs...\nLooks like you won!!")
        elif answer == "no":
            print("\nAs you walked away from her you heard her jump, the splash of water, her screams and then you turned back and saw the alligator kill her and all the blood in the water. You regret not helping her when you could and end up going into depression and have anxiety attacks and nightmares about that night and one day.....you jump off from the very edge of the bridge and commit suicide...\nLooks like you lose!!")
        else:
            print("\nNot a valid option...\nYou lose!!")
    else:
        print("\nNot a valid option...\nYou lose!!")
elif answer == "straight":
    answer = input("\nSo you keep going on the same path and see a bar next to the road. Do you go in (yes/no)? ").lower()
    if answer == "yes":
        anwser = input("\nWhen you go into the bar you order chicken wings with beer...\nBut there is a big guy in the corner who is constantly watching you around 6'5 weighing 270lbs. Do you go and confront him (yes/no)? ")
        if answer == "yes":
            print("\nYou go near him and ask him 'Hey man....what's your problem?? Why you staring at me?\nHe replies: 'I think I recognize you from somewhere'\nYou say:'I don't think we've ever met...I'd remember that ugly face of yours for sure'\nJust after listening to that a fight breaks out between you two and the police arrives and arrests you both...\nLooks like you lose!!")
        elif answer == "no":
            print("You eat your chicken wings drink your beer, walk out that bar and walk home...\nYou win!!")
        else:
            print("\nNot a valid option...\nYou lose!!")
    elif answer == "no":
        anwser = input("\nYou keep walking and now you're tired...\nBut your'e broke so you just wait there for a truck or a vehicle to give you a ride. \nAfter a few minutes a car arrived and offered you a ride. A teenager is driving the car and is probably high. But there might not be another vehicle in this road for a long time and you are tired, hungry and thirsty at the same time. Do you go in (yes/no)? ")
        if answer == "yes":
            print("\n After you sat in the boy offers you water and some food then starts driving. After a few minutes 2 trucks come from the opposite direction and the car crashes and you end up dead....\n Looks like you lost!!")
        elif answer == "no":
            print("\n The car went away and you are laying there hungry and thirsty, finally after 30 long minutes a truck arrives and the driver picks you up and drops you home\nLooks like you wonnn!!!")
        else:
            print("\nNot a valid option...\nYou lose!!")
    else:
        print("\nNot a valid option...\nYou lose!!")
else:
    print("\nNot a valid option...\nYou lose!!")
